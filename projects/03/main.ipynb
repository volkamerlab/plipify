# %% [markdown]
# # Automated interaction statistics

# %% [markdown]
# This notebooks aims to provide an automated pipeline to generate **protein-ligand interaction statistics** for any protein with available protein:ligand complexes in the PDB. The only required parameter is the **UniProt ID** of the protein of interest.

# %% [markdown]
# ## Content
# * Data collection
#     * Collect relevant pdb codes
#     * Collect ligands bound to PDB structures
#     * Download and prepare runumbered structures
# * Data processing
#     * Load structures
#     * Identify common residues
#     * Generate pocket mappings
# * Interaction statistics
#     * Generate interaction fingerprint
#     * Apply KLIFS rediue numbering (if applicable)

# %%
import json
from pathlib import Path
import urllib
import zlib

import biotite.database.rcsb as rcsb
import requests
from tqdm.auto import tqdm

from plipify.core import Structure
from plipify.fingerprints import InteractionFingerprint

# %% [markdown]
# Beside the [UniProt](https://www.uniprot.org/) ID, one can further customize the PDB query for potential protein:ligand complexes, i.e.
# * number of mutations,
# * experimental method,
# * ligand type,
# * and the molecular weight of the co-crystallized ligand(s)
#
# The pipeline is exemplified for the protein kinase **ABL1** ([P00519](https://www.uniprot.org/uniprot/P00519)).

# %%
uniprot_id = "P00519"  # ABL1
#uniprot_id = "P00533"  # EGFR
#uniprot_id = "Q9NRG4"  # SMYD2
max_mutation_count = 0
experimental_method = "X-RAY DIFFRACTION"
ligand_type = "non-polymer"
ligand_mw = (300, 500)

# %% [markdown]
# Create data folder (if it does not exist yet)

# %%
HERE = Path(_dh[-1])
DATA = HERE / "data" / uniprot_id
DATA.mkdir(exist_ok=True, parents=True)

# %% [markdown]
# # Data collection

# %% [markdown]
# ## Collect relevant pdb codes

# %% [markdown]
# In the next step, biotite's [rcsb module](https://www.biotite-python.org/apidoc/biotite.database.rcsb.html#module-biotite.database.rcsb) will be used to query the PDB for relevant structures. The query is thereby customized by the parameters given above.
# * Collect individual query strings
# * Combine them and query PDB

# %%
query_by_uniprot = rcsb.FieldQuery(
    "rcsb_polymer_entity_container_identifiers.reference_sequence_identifiers.database_name",
    exact_match="UniProt"
)
query_by_uniprot_id = rcsb.FieldQuery(
    "rcsb_polymer_entity_container_identifiers.reference_sequence_identifiers.database_accession",
    exact_match=uniprot_id
)
query_mutation_count = rcsb.FieldQuery(
    "entity_poly.rcsb_mutation_count",
    range_closed=(0, max_mutation_count)
)
query_by_experimental_method = rcsb.FieldQuery(
    "exptl.method",
    exact_match=experimental_method
)
query_by_ligand_type = rcsb.FieldQuery(
    "chem_comp.type",
    exact_match=ligand_type
)
query_by_ligand_mw = rcsb.FieldQuery(
    "chem_comp.formula_weight",
    range_closed=ligand_mw
)

# %% [markdown]
# Compose query.

# %%
results = rcsb.search(
    rcsb.CompositeQuery(
        [
            query_by_uniprot,
            query_by_uniprot_id,
            query_mutation_count,
            query_by_experimental_method,
            query_by_ligand_type,
            query_by_ligand_mw
        ],
        operator="and"
    ),
    return_type="polymer_instance"
)

# %% [markdown]
# Collect matching pdb

# %%
pdbs = []
for result in results:
    pdb_id, chain = result.split(".")
    pdbs.append({"pdb_id": pdb_id, "chain": chain})

print(f"Found {len(pdbs)} structures in the PDB.")
# Out:
# Found 30 structures in the PDB.

# %% [markdown]
# ## Collect ligands bound to PDB structures

# %% [markdown]
# Currently, it seems not possible to query the PDB about co-crystallized ligands in a programmatic fashion. Hence, we will perform manual requests and directly filter for ligands with a matching molecular weight.

# %%
base_url = "https://data.rcsb.org/graphql?query="
potential_complexes = []
for pdb in tqdm(pdbs):
    pdb_id = pdb["pdb_id"]
    query = '{entry(entry_id:"' + pdb_id + '"){nonpolymer_entities{nonpolymer_comp{chem_comp{id,formula_weight}}}}}'
    response = requests.get(base_url + urllib.parse.quote(query))
    potential_ligands = json.loads(response.text)["data"]["entry"]["nonpolymer_entities"]
    # remove ligands without molecular weight
    potential_ligands = [
        ligand
        for ligand in potential_ligands 
        if ligand["nonpolymer_comp"]["chem_comp"]["formula_weight"] is not None
    ]
    # filter for molecular weight
    ligands = [
        ligand["nonpolymer_comp"]["chem_comp"]["id"]
        for ligand in potential_ligands 
        if ligand_mw[0] <= ligand["nonpolymer_comp"]["chem_comp"]["formula_weight"] <= ligand_mw[1]
    ]
    # collect chain:ligand pairs
    for ligand in ligands:
        potential_complexes.append(
            {"pdb_id": pdb_id, 
             "chain": pdb["chain"],
             "ligand": ligand}
        )
print(f"Identified {len(potential_complexes)} potential protein[chain]:ligand complexes.")
# Out:
#   0%|          | 0/30 [00:00<?, ?it/s]
# Identified 44 potential protein[chain]:ligand complexes.

# %% [markdown]
# ## Download and prepare renumbered structures

# %% [markdown]
# Structures of the same protein deposited in the PDB are not guaranteed to have the same residue numbering. However, this is important for plipify to compare interactions between different structures. Luckily, the Dunbrack Lab provides the [PDBrenum](http://dunbrack3.fccc.edu/PDBrenum/) service that allows to renumber structures according to the UniProt ID. The following code will download the respective structures and prepare separate file for each chain:ligand combination.

# %%
valid_complexes = []
for potential_complex in tqdm(potential_complexes):
    pdb_id = potential_complex["pdb_id"]
    chain = potential_complex["chain"]
    ligand = potential_complex["ligand"]
    pdb_path = DATA / f"{pdb_id}_{chain}_{ligand}.pdb"
    response = requests.get(f"http://dunbrack3.fccc.edu/PDBrenum/output_PDB/{pdb_id.lower()}_renum.pdb.gz")
    ligand_identified = False
    with open(pdb_path, "w") as pdb_file:
        for line in zlib.decompress(response.content, 15+32).decode("utf-8").split("\n"):
            if line.startswith(("ATOM", "HETATM", "ANISOU", "TER")):
                if line[21] == chain:  # filter for chain
                    if line.startswith("HETATM"):
                        if line[17:20] == ligand:  # filter for ligand, might be problematic for co-factors
                            ligand_identified = True
                            pdb_file.write(line + "\n")
                    else:
                        pdb_file.write(line + "\n")
            else:
                pdb_file.write(line + "\n")
    # remove structure without accompanying ligand
    if not ligand_identified:
        pdb_path.unlink()
    else:
        potential_complex["file_path"] = pdb_path
        valid_complexes.append(potential_complex)

print(f"Generated separate PDB files for {len(valid_complexes)} protein[chain]:ligand complexes.")
# Out:
#   0%|          | 0/44 [00:00<?, ?it/s]
# Generated separate PDB files for 40 protein[chain]:ligand complexes.

# %% [markdown]
# # Data processing

# %% [markdown]
# ## Load structures

# %% [markdown]
# Next, all structures will be loaded into plipify and checked for the existence of multiple ligands. This can happen if the same ligand is present twice in the same chain, e.g. 5V3H.

# %%
valid_structures = []
for valid_complex in tqdm(valid_complexes):
    structure = Structure.from_pdbfile(str(valid_complex["file_path"]))
    if len(structure.binding_sites) != 1:
        print(f"{valid_complex['pdb_id']} chain {valid_complex['chain']} contains {len(structure.binding_sites)} binding sites but we want exactly one.")
    else:
        valid_structures.append(structure)
print(f"Generated {len(valid_structures)} valid protein[chain]:ligand complexes.")
# Out:
#   0%|          | 0/40 [00:00<?, ?it/s]
# Generated 40 valid protein[chain]:ligand complexes.

# %% [markdown]
# ## Identify common residues

# %% [markdown]
# Additionally, we will restrict the interaction analysis to the residues that are common to all structures.

# %%
resid_sets = []
for structure in valid_structures:
    protein_resids = [residue.seq_index for residue in structure.residues if residue.is_protein()]
    resid_sets.append(set(protein_resids))

common_resids = resid_sets[0].intersection(*resid_sets)
print(f"Identified {len(common_resids)} residues common to all structures.")
# Out:
# Identified 202 residues common to all structures.

# %% [markdown]
# ## Generate pocket mappings

# %% [markdown]
# These common residues can be passed as pocket mappings to plipify to generate the interaction statistics.

# %%
pocket_mappings = []
for structure in valid_structures:
    chain = structure.identifier.split("_")[1]
    mapping = {}
    for common_resid in common_resids:
        mapping[common_resid] = {
            "seq_index": common_resid,
            "chain": chain,
        }
    pocket_mappings.append(mapping)

# %% [markdown]
# # Interaction statistics

# %% [markdown]
# ## Generate interaction fingerprint

# %% [markdown]
# Finally, the interaction fingerprint will be generated.

# %%
fp = InteractionFingerprint().calculate_fingerprint(
        valid_structures,
        residue_indices=pocket_mappings,
        labeled=True, 
        as_dataframe=True, 
        remove_non_interacting_residues=True,
        remove_empty_interaction_types=True,
        ensure_same_sequence=False
    )

if not fp.values.shape[0]:
    raise ValueError("Fingerprint is empty!")

# %% [markdown]
# Show the dataframe with interactions colored by frequency.

# %%
fp.style.background_gradient(axis=None, cmap="YlGnBu")
# Out:
# <style  type="text/css" >
# #T_77dfa_row0_col0{
#             background-color:  #102369;
#             color:  #f1f1f1;
#         }#T_77dfa_row0_col1,#T_77dfa_row0_col2,#T_77dfa_row0_col3,#T_77dfa_row0_col4,#T_77dfa_row0_col5,#T_77dfa_row0_col6,#T_77dfa_row1_col1,#T_77dfa_row1_col2,#T_77dfa_row1_col3,#T_77dfa_row1_col4,#T_77dfa_row1_col5,#T_77dfa_row1_col6,#T_77dfa_row2_col1,#T_77dfa_row2_col2,#T_77dfa_row2_col3,#T_77dfa_row2_col4,#T_77dfa_row2_col5,#T_77dfa_row2_col6,#T_77dfa_row3_col1,#T_77dfa_row3_col3,#T_77dfa_row3_col5,#T_77dfa_row3_col6,#T_77dfa_row4_col1,#T_77dfa_row4_col2,#T_77dfa_row4_col3,#T_77dfa_row4_col4,#T_77dfa_row4_col5,#T_77dfa_row5_col2,#T_77dfa_row5_col3,#T_77dfa_row5_col4,#T_77dfa_row5_col6,#T_77dfa_row6_col1,#T_77dfa_row6_col2,#T_77dfa_row6_col3,#T_77dfa_row6_col4,#T_77dfa_row6_col5,#T_77dfa_row6_col6,#T_77dfa_row7_col1,#T_77dfa_row7_col2,#T_77dfa_row7_col3,#T_77dfa_row7_col4,#T_77dfa_row7_col5,#T_77dfa_row7_col6,#T_77dfa_row8_col1,#T_77dfa_row8_col2,#T_77dfa_row8_col3,#T_77dfa_row8_col4,#T_77dfa_row8_col5,#T_77dfa_row8_col6,#T_77dfa_row9_col1,#T_77dfa_row9_col2,#T_77dfa_row9_col3,#T_77dfa_row9_col4,#T_77dfa_row9_col5,#T_77dfa_row9_col6,#T_77dfa_row10_col3,#T_77dfa_row10_col4,#T_77dfa_row10_col5,#T_77dfa_row10_col6,#T_77dfa_row11_col0,#T_77dfa_row11_col1,#T_77dfa_row11_col3,#T_77dfa_row11_col4,#T_77dfa_row11_col5,#T_77dfa_row11_col6,#T_77dfa_row12_col1,#T_77dfa_row12_col2,#T_77dfa_row12_col3,#T_77dfa_row12_col5,#T_77dfa_row12_col6,#T_77dfa_row13_col0,#T_77dfa_row13_col3,#T_77dfa_row13_col4,#T_77dfa_row13_col5,#T_77dfa_row13_col6,#T_77dfa_row14_col1,#T_77dfa_row14_col2,#T_77dfa_row14_col3,#T_77dfa_row14_col4,#T_77dfa_row14_col5,#T_77dfa_row14_col6,#T_77dfa_row15_col0,#T_77dfa_row15_col2,#T_77dfa_row15_col3,#T_77dfa_row15_col4,#T_77dfa_row15_col5,#T_77dfa_row15_col6,#T_77dfa_row16_col0,#T_77dfa_row16_col2,#T_77dfa_row16_col3,#T_77dfa_row16_col4,#T_77dfa_row16_col5,#T_77dfa_row16_col6,#T_77dfa_row17_col0,#T_77dfa_row17_col2,#T_77dfa_row17_col3,#T_77dfa_row17_col4,#T_77dfa_row17_col5,#T_77dfa_row17_col6,#T_77dfa_row18_col0,#T_77dfa_row18_col2,#T_77dfa_row18_col3,#T_77dfa_row18_col4,#T_77dfa_row18_col5,#T_77dfa_row18_col6,#T_77dfa_row19_col1,#T_77dfa_row19_col2,#T_77dfa_row19_col3,#T_77dfa_row19_col4,#T_77dfa_row19_col5,#T_77dfa_row19_col6,#T_77dfa_row20_col1,#T_77dfa_row20_col2,#T_77dfa_row20_col3,#T_77dfa_row20_col4,#T_77dfa_row20_col5,#T_77dfa_row20_col6,#T_77dfa_row21_col1,#T_77dfa_row21_col2,#T_77dfa_row21_col3,#T_77dfa_row21_col4,#T_77dfa_row21_col5,#T_77dfa_row21_col6,#T_77dfa_row22_col0,#T_77dfa_row22_col1,#T_77dfa_row22_col2,#T_77dfa_row22_col3,#T_77dfa_row22_col4,#T_77dfa_row22_col6,#T_77dfa_row23_col0,#T_77dfa_row23_col1,#T_77dfa_row23_col3,#T_77dfa_row23_col4,#T_77dfa_row23_col5,#T_77dfa_row23_col6,#T_77dfa_row24_col1,#T_77dfa_row24_col2,#T_77dfa_row24_col3,#T_77dfa_row24_col4,#T_77dfa_row24_col5,#T_77dfa_row24_col6,#T_77dfa_row25_col1,#T_77dfa_row25_col2,#T_77dfa_row25_col3,#T_77dfa_row25_col4,#T_77dfa_row25_col5,#T_77dfa_row25_col6,#T_77dfa_row26_col2,#T_77dfa_row26_col4,#T_77dfa_row26_col5,#T_77dfa_row26_col6,#T_77dfa_row27_col1,#T_77dfa_row27_col2,#T_77dfa_row27_col3,#T_77dfa_row27_col4,#T_77dfa_row27_col5,#T_77dfa_row27_col6,#T_77dfa_row28_col0,#T_77dfa_row28_col2,#T_77dfa_row28_col3,#T_77dfa_row28_col4,#T_77dfa_row28_col5,#T_77dfa_row28_col6,#T_77dfa_row29_col0,#T_77dfa_row29_col1,#T_77dfa_row29_col2,#T_77dfa_row29_col3,#T_77dfa_row29_col4,#T_77dfa_row29_col5,#T_77dfa_row30_col1,#T_77dfa_row30_col2,#T_77dfa_row30_col3,#T_77dfa_row30_col4,#T_77dfa_row30_col5,#T_77dfa_row30_col6,#T_77dfa_row31_col1,#T_77dfa_row31_col3,#T_77dfa_row31_col4,#T_77dfa_row31_col5,#T_77dfa_row31_col6,#T_77dfa_row32_col1,#T_77dfa_row32_col2,#T_77dfa_row32_col3,#T_77dfa_row32_col4,#T_77dfa_row32_col5,#T_77dfa_row32_col6,#T_77dfa_row33_col3,#T_77dfa_row33_col4,#T_77dfa_row33_col5,#T_77dfa_row33_col6,#T_77dfa_row34_col1,#T_77dfa_row34_col2,#T_77dfa_row34_col3,#T_77dfa_row34_col4,#T_77dfa_row34_col5,#T_77dfa_row34_col6,#T_77dfa_row35_col1,#T_77dfa_row35_col2,#T_77dfa_row35_col3,#T_77dfa_row35_col4,#T_77dfa_row35_col5,#T_77dfa_row35_col6{
#             background-color:  #ffffd9;
#             color:  #000000;
#         }#T_77dfa_row1_col0{
#             background-color:  #5dc0c0;
#             color:  #000000;
#         }#T_77dfa_row2_col0,#T_77dfa_row4_col6,#T_77dfa_row6_col0,#T_77dfa_row21_col0,#T_77dfa_row23_col2,#T_77dfa_row33_col0,#T_77dfa_row33_col1{
#             background-color:  #f5fbc2;
#             color:  #000000;
#         }#T_77dfa_row3_col0,#T_77dfa_row25_col0,#T_77dfa_row28_col1,#T_77dfa_row29_col6,#T_77dfa_row31_col2,#T_77dfa_row34_col0,#T_77dfa_row35_col0{
#             background-color:  #e7f6b1;
#             color:  #000000;
#         }#T_77dfa_row3_col2,#T_77dfa_row3_col4,#T_77dfa_row5_col1,#T_77dfa_row8_col0,#T_77dfa_row11_col2,#T_77dfa_row12_col4,#T_77dfa_row14_col0,#T_77dfa_row15_col1,#T_77dfa_row16_col1,#T_77dfa_row18_col1,#T_77dfa_row22_col5,#T_77dfa_row30_col0{
#             background-color:  #fafdce;
#             color:  #000000;
#         }#T_77dfa_row4_col0,#T_77dfa_row5_col0{
#             background-color:  #4ab9c3;
#             color:  #000000;
#         }#T_77dfa_row5_col5,#T_77dfa_row17_col1,#T_77dfa_row32_col0,#T_77dfa_row33_col2{
#             background-color:  #eff9b6;
#             color:  #000000;
#         }#T_77dfa_row7_col0{
#             background-color:  #83cebb;
#             color:  #000000;
#         }#T_77dfa_row9_col0,#T_77dfa_row24_col0,#T_77dfa_row27_col0{
#             background-color:  #2354a3;
#             color:  #f1f1f1;
#         }#T_77dfa_row10_col0{
#             background-color:  #1f80b8;
#             color:  #000000;
#         }#T_77dfa_row10_col1,#T_77dfa_row10_col2{
#             background-color:  #3cb1c3;
#             color:  #000000;
#         }#T_77dfa_row12_col0,#T_77dfa_row19_col0{
#             background-color:  #6fc7bd;
#             color:  #000000;
#         }#T_77dfa_row13_col1{
#             background-color:  #081d58;
#             color:  #f1f1f1;
#         }#T_77dfa_row13_col2{
#             background-color:  #97d6b9;
#             color:  #000000;
#         }#T_77dfa_row20_col0,#T_77dfa_row31_col0{
#             background-color:  #d0edb3;
#             color:  #000000;
#         }#T_77dfa_row26_col0{
#             background-color:  #1d8ebf;
#             color:  #000000;
#         }#T_77dfa_row26_col1{
#             background-color:  #269bc1;
#             color:  #000000;
#         }#T_77dfa_row26_col3{
#             background-color:  #aedfb6;
#             color:  #000000;
#         }</style><table id="T_77dfa_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >hydrophobic</th>        <th class="col_heading level0 col1" >hbond-don</th>        <th class="col_heading level0 col2" >hbond-acc</th>        <th class="col_heading level0 col3" >saltbridge</th>        <th class="col_heading level0 col4" >pistacking</th>        <th class="col_heading level0 col5" >pication</th>        <th class="col_heading level0 col6" >halogen</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_77dfa_level0_row0" class="row_heading level0 row0" >248</th>
#                         <td id="T_77dfa_row0_col0" class="data row0 col0" >26</td>
#                         <td id="T_77dfa_row0_col1" class="data row0 col1" >0</td>
#                         <td id="T_77dfa_row0_col2" class="data row0 col2" >0</td>
#                         <td id="T_77dfa_row0_col3" class="data row0 col3" >0</td>
#                         <td id="T_77dfa_row0_col4" class="data row0 col4" >0</td>
#                         <td id="T_77dfa_row0_col5" class="data row0 col5" >0</td>
#                         <td id="T_77dfa_row0_col6" class="data row0 col6" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_77dfa_level0_row1" class="row_heading level0 row1" >256</th>
#                         <td id="T_77dfa_row1_col0" class="data row1 col0" >12</td>
#                         <td id="T_77dfa_row1_col1" class="data row1 col1" >0

# %% [markdown]
# ## Apply KLIFS residue numbering (if applicable)
# In this example, we chose a kinase example, thus, we decided to convert the residue numbers to the [KLIFS](https://klifs.net/) numbering scheme.
#
# Note:
# * If you are workin with a different protein, please skip these steps.
# * Or if you work with another protein family for which such a numbering scheme is available, it could be integrated as well.

# %%
from opencadd.databases.klifs import setup_remote

# %%
# Set up remote session
klifs = setup_remote()

# %% [markdown]
# Note: `klifs_kinase_ID` for the kinase was checked manually.

# %%
klifs_kinase_id = 1061  # ABL1 4WA9
pocket = klifs.pockets.by_structure_klifs_id(klifs_kinase_id)

# %% [markdown]
# Reindex the interactions statistics dataframe.

# %%
for index in fp.index:
    try:
        klifs_resid = int(pocket[pocket["residue.id"] == str(index)]["residue.klifs_id"].iloc[0])
    except IndexError:
        continue
    fp.rename(index={index: f"KLI{klifs_resid:02d}"}, inplace=True)

# %% [markdown]
# Show the dataframe with interactions colored by frequency.

# %%
fp.style.background_gradient(axis=None, cmap="YlGnBu")
# Out:
# <style  type="text/css" >
# #T_ba5b2_row0_col0{
#             background-color:  #102369;
#             color:  #f1f1f1;
#         }#T_ba5b2_row0_col1,#T_ba5b2_row0_col2,#T_ba5b2_row0_col3,#T_ba5b2_row0_col4,#T_ba5b2_row0_col5,#T_ba5b2_row0_col6,#T_ba5b2_row1_col1,#T_ba5b2_row1_col2,#T_ba5b2_row1_col3,#T_ba5b2_row1_col4,#T_ba5b2_row1_col5,#T_ba5b2_row1_col6,#T_ba5b2_row2_col1,#T_ba5b2_row2_col2,#T_ba5b2_row2_col3,#T_ba5b2_row2_col4,#T_ba5b2_row2_col5,#T_ba5b2_row2_col6,#T_ba5b2_row3_col1,#T_ba5b2_row3_col3,#T_ba5b2_row3_col5,#T_ba5b2_row3_col6,#T_ba5b2_row4_col1,#T_ba5b2_row4_col2,#T_ba5b2_row4_col3,#T_ba5b2_row4_col4,#T_ba5b2_row4_col5,#T_ba5b2_row5_col2,#T_ba5b2_row5_col3,#T_ba5b2_row5_col4,#T_ba5b2_row5_col6,#T_ba5b2_row6_col1,#T_ba5b2_row6_col2,#T_ba5b2_row6_col3,#T_ba5b2_row6_col4,#T_ba5b2_row6_col5,#T_ba5b2_row6_col6,#T_ba5b2_row7_col1,#T_ba5b2_row7_col2,#T_ba5b2_row7_col3,#T_ba5b2_row7_col4,#T_ba5b2_row7_col5,#T_ba5b2_row7_col6,#T_ba5b2_row8_col1,#T_ba5b2_row8_col2,#T_ba5b2_row8_col3,#T_ba5b2_row8_col4,#T_ba5b2_row8_col5,#T_ba5b2_row8_col6,#T_ba5b2_row9_col1,#T_ba5b2_row9_col2,#T_ba5b2_row9_col3,#T_ba5b2_row9_col4,#T_ba5b2_row9_col5,#T_ba5b2_row9_col6,#T_ba5b2_row10_col3,#T_ba5b2_row10_col4,#T_ba5b2_row10_col5,#T_ba5b2_row10_col6,#T_ba5b2_row11_col0,#T_ba5b2_row11_col1,#T_ba5b2_row11_col3,#T_ba5b2_row11_col4,#T_ba5b2_row11_col5,#T_ba5b2_row11_col6,#T_ba5b2_row12_col1,#T_ba5b2_row12_col2,#T_ba5b2_row12_col3,#T_ba5b2_row12_col5,#T_ba5b2_row12_col6,#T_ba5b2_row13_col0,#T_ba5b2_row13_col3,#T_ba5b2_row13_col4,#T_ba5b2_row13_col5,#T_ba5b2_row13_col6,#T_ba5b2_row14_col1,#T_ba5b2_row14_col2,#T_ba5b2_row14_col3,#T_ba5b2_row14_col4,#T_ba5b2_row14_col5,#T_ba5b2_row14_col6,#T_ba5b2_row15_col0,#T_ba5b2_row15_col2,#T_ba5b2_row15_col3,#T_ba5b2_row15_col4,#T_ba5b2_row15_col5,#T_ba5b2_row15_col6,#T_ba5b2_row16_col0,#T_ba5b2_row16_col2,#T_ba5b2_row16_col3,#T_ba5b2_row16_col4,#T_ba5b2_row16_col5,#T_ba5b2_row16_col6,#T_ba5b2_row17_col0,#T_ba5b2_row17_col2,#T_ba5b2_row17_col3,#T_ba5b2_row17_col4,#T_ba5b2_row17_col5,#T_ba5b2_row17_col6,#T_ba5b2_row18_col0,#T_ba5b2_row18_col2,#T_ba5b2_row18_col3,#T_ba5b2_row18_col4,#T_ba5b2_row18_col5,#T_ba5b2_row18_col6,#T_ba5b2_row19_col1,#T_ba5b2_row19_col2,#T_ba5b2_row19_col3,#T_ba5b2_row19_col4,#T_ba5b2_row19_col5,#T_ba5b2_row19_col6,#T_ba5b2_row20_col1,#T_ba5b2_row20_col2,#T_ba5b2_row20_col3,#T_ba5b2_row20_col4,#T_ba5b2_row20_col5,#T_ba5b2_row20_col6,#T_ba5b2_row21_col1,#T_ba5b2_row21_col2,#T_ba5b2_row21_col3,#T_ba5b2_row21_col4,#T_ba5b2_row21_col5,#T_ba5b2_row21_col6,#T_ba5b2_row22_col0,#T_ba5b2_row22_col1,#T_ba5b2_row22_col2,#T_ba5b2_row22_col3,#T_ba5b2_row22_col4,#T_ba5b2_row22_col6,#T_ba5b2_row23_col0,#T_ba5b2_row23_col1,#T_ba5b2_row23_col3,#T_ba5b2_row23_col4,#T_ba5b2_row23_col5,#T_ba5b2_row23_col6,#T_ba5b2_row24_col1,#T_ba5b2_row24_col2,#T_ba5b2_row24_col3,#T_ba5b2_row24_col4,#T_ba5b2_row24_col5,#T_ba5b2_row24_col6,#T_ba5b2_row25_col1,#T_ba5b2_row25_col2,#T_ba5b2_row25_col3,#T_ba5b2_row25_col4,#T_ba5b2_row25_col5,#T_ba5b2_row25_col6,#T_ba5b2_row26_col2,#T_ba5b2_row26_col4,#T_ba5b2_row26_col5,#T_ba5b2_row26_col6,#T_ba5b2_row27_col1,#T_ba5b2_row27_col2,#T_ba5b2_row27_col3,#T_ba5b2_row27_col4,#T_ba5b2_row27_col5,#T_ba5b2_row27_col6,#T_ba5b2_row28_col0,#T_ba5b2_row28_col2,#T_ba5b2_row28_col3,#T_ba5b2_row28_col4,#T_ba5b2_row28_col5,#T_ba5b2_row28_col6,#T_ba5b2_row29_col0,#T_ba5b2_row29_col1,#T_ba5b2_row29_col2,#T_ba5b2_row29_col3,#T_ba5b2_row29_col4,#T_ba5b2_row29_col5,#T_ba5b2_row30_col1,#T_ba5b2_row30_col2,#T_ba5b2_row30_col3,#T_ba5b2_row30_col4,#T_ba5b2_row30_col5,#T_ba5b2_row30_col6,#T_ba5b2_row31_col1,#T_ba5b2_row31_col3,#T_ba5b2_row31_col4,#T_ba5b2_row31_col5,#T_ba5b2_row31_col6,#T_ba5b2_row32_col1,#T_ba5b2_row32_col2,#T_ba5b2_row32_col3,#T_ba5b2_row32_col4,#T_ba5b2_row32_col5,#T_ba5b2_row32_col6,#T_ba5b2_row33_col3,#T_ba5b2_row33_col4,#T_ba5b2_row33_col5,#T_ba5b2_row33_col6,#T_ba5b2_row34_col1,#T_ba5b2_row34_col2,#T_ba5b2_row34_col3,#T_ba5b2_row34_col4,#T_ba5b2_row34_col5,#T_ba5b2_row34_col6,#T_ba5b2_row35_col1,#T_ba5b2_row35_col2,#T_ba5b2_row35_col3,#T_ba5b2_row35_col4,#T_ba5b2_row35_col5,#T_ba5b2_row35_col6{
#             background-color:  #ffffd9;
#             color:  #000000;
#         }#T_ba5b2_row1_col0{
#             background-color:  #5dc0c0;
#             color:  #000000;
#         }#T_ba5b2_row2_col0,#T_ba5b2_row4_col6,#T_ba5b2_row6_col0,#T_ba5b2_row21_col0,#T_ba5b2_row23_col2,#T_ba5b2_row33_col0,#T_ba5b2_row33_col1{
#             background-color:  #f5fbc2;
#             color:  #000000;
#         }#T_ba5b2_row3_col0,#T_ba5b2_row25_col0,#T_ba5b2_row28_col1,#T_ba5b2_row29_col6,#T_ba5b2_row31_col2,#T_ba5b2_row34_col0,#T_ba5b2_row35_col0{
#             background-color:  #e7f6b1;
#             color:  #000000;
#         }#T_ba5b2_row3_col2,#T_ba5b2_row3_col4,#T_ba5b2_row5_col1,#T_ba5b2_row8_col0,#T_ba5b2_row11_col2,#T_ba5b2_row12_col4,#T_ba5b2_row14_col0,#T_ba5b2_row15_col1,#T_ba5b2_row16_col1,#T_ba5b2_row18_col1,#T_ba5b2_row22_col5,#T_ba5b2_row30_col0{
#             background-color:  #fafdce;
#             color:  #000000;
#         }#T_ba5b2_row4_col0,#T_ba5b2_row5_col0{
#             background-color:  #4ab9c3;
#             color:  #000000;
#         }#T_ba5b2_row5_col5,#T_ba5b2_row17_col1,#T_ba5b2_row32_col0,#T_ba5b2_row33_col2{
#             background-color:  #eff9b6;
#             color:  #000000;
#         }#T_ba5b2_row7_col0{
#             background-color:  #83cebb;
#             color:  #000000;
#         }#T_ba5b2_row9_col0,#T_ba5b2_row24_col0,#T_ba5b2_row27_col0{
#             background-color:  #2354a3;
#             color:  #f1f1f1;
#         }#T_ba5b2_row10_col0{
#             background-color:  #1f80b8;
#             color:  #000000;
#         }#T_ba5b2_row10_col1,#T_ba5b2_row10_col2{
#             background-color:  #3cb1c3;
#             color:  #000000;
#         }#T_ba5b2_row12_col0,#T_ba5b2_row19_col0{
#             background-color:  #6fc7bd;
#             color:  #000000;
#         }#T_ba5b2_row13_col1{
#             background-color:  #081d58;
#             color:  #f1f1f1;
#         }#T_ba5b2_row13_col2{
#             background-color:  #97d6b9;
#             color:  #000000;
#         }#T_ba5b2_row20_col0,#T_ba5b2_row31_col0{
#             background-color:  #d0edb3;
#             color:  #000000;
#         }#T_ba5b2_row26_col0{
#             background-color:  #1d8ebf;
#             color:  #000000;
#         }#T_ba5b2_row26_col1{
#             background-color:  #269bc1;
#             color:  #000000;
#         }#T_ba5b2_row26_col3{
#             background-color:  #aedfb6;
#             color:  #000000;
#         }</style><table id="T_ba5b2_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >hydrophobic</th>        <th class="col_heading level0 col1" >hbond-don</th>        <th class="col_heading level0 col2" >hbond-acc</th>        <th class="col_heading level0 col3" >saltbridge</th>        <th class="col_heading level0 col4" >pistacking</th>        <th class="col_heading level0 col5" >pication</th>        <th class="col_heading level0 col6" >halogen</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_ba5b2_level0_row0" class="row_heading level0 row0" >KLI03</th>
#                         <td id="T_ba5b2_row0_col0" class="data row0 col0" >26</td>
#                         <td id="T_ba5b2_row0_col1" class="data row0 col1" >0</td>
#                         <td id="T_ba5b2_row0_col2" class="data row0 col2" >0</td>
#                         <td id="T_ba5b2_row0_col3" class="data row0 col3" >0</td>
#                         <td id="T_ba5b2_row0_col4" class="data row0 col4" >0</td>
#                         <td id="T_ba5b2_row0_col5" class="data row0 col5" >0</td>
#                         <td id="T_ba5b2_row0_col6" class="data row0 col6" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_ba5b2_level0_row1" class="row_heading level0 row1" >KLI11</th>
#                         <td id="T_ba5b2_row1_col0" class="data row1 col0" >12</td>
#                         <td id="T_ba5b2_row1_col1" class="data row1 col1
